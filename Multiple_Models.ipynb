# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
batch_size = 70
img_dir='C:\\Users\\anne.klaver\\Documents\\Period 2 - Applied Machine Learning\\train_set\\train_set\\train_set'#traindata directory
train_datagen = ImageDataGenerator(
    zoom_range=0.3, rotation_range=50,
    width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
    horizontal_flip=True, fill_mode='nearest',
    rescale=1/255,
    validation_split=0.2
)


# Notice the tiny target size, just 48x48!
train_generator = train_datagen.flow_from_directory(
    img_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
)
validation_generator = train_datagen.flow_from_directory(
    img_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# %%
from keras.layers import Dense, AveragePooling2D
from keras import Model
prior = keras.applications.DenseNet121(#Name of model (Xception,inceptionV3,VGG16,VGG19,Resnet50)
    include_top=False, 
    weights='imagenet',
    input_shape=(224, 224, 3)
)

for cnn_block_layer in prior.layers:
    cnn_block_layer.trainable = False
    
x = prior.output
#Fully-connected layer
x=Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)
#Logistic layer (80 classes)
predictions = Dense(80, activation='softmax')(x)

model = Model(inputs=prior.input, outputs=predictions)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
from keras.callbacks import ModelCheckpoint
model.fit_generator(
    train_generator,
    steps_per_epoch=(len(train_generator.filenames)//batch_size),
    epochs=5,
    validation_data=validation_generator,
    validation_steps=(len(validation_generator.filenames)//batch_size),
    
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True),
        ModelCheckpoint(filepath='model-.{epoch:02d}-{val_loss:.2f}.hdf5', verbose=1, save_best_only=True),
        ReduceLROnPlateau(patience=2)
    ]
)

from keras.optimizers import SGD
    
for layer in model.layers[-7:]:
    layer.trainable=True
    
model.compile(
    optimizer=SGD(lr=0.0001, momentum=0.9),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
from keras.callbacks import ModelCheckpoint
model.fit_generator(
    train_generator,
    steps_per_epoch=(len(train_generator.filenames)//batch_size),
    epochs=5,
    validation_data=validation_generator,
    validation_steps=(len(validation_generator.filenames)//batch_size),
    
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True),
        ModelCheckpoint(filepath='model2-.{epoch:02d}-{val_loss:.2f}.hdf5', verbose=1, save_best_only=True),
        ReduceLROnPlateau(patience=2)
    ]
)
for layer in model.layers[-11:]:
    layer.trainable=True

model.compile(
    optimizer=SGD(lr=0.0001, momentum=0.9),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

from keras.callbacks import ModelCheckpoint
model.fit_generator(
    train_generator,
    steps_per_epoch=(len(train_generator.filenames)//batch_size),
    epochs=5,
    validation_data=validation_generator,
    validation_steps=(len(validation_generator.filenames)//batch_size),
    
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True),
        ModelCheckpoint(filepath='model3-.{epoch:02d}-{val_loss:.2f}.hdf5', verbose=1, save_best_only=True),
        ReduceLROnPlateau(patience=2)
    ]
)
for layer in model.layers[-15:]:
    layer.trainable=True

model.compile(
    optimizer=SGD(lr=0.0001, momentum=0.9),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

from keras.callbacks import ModelCheckpoint
model.fit_generator(
    train_generator,
    steps_per_epoch=(len(train_generator.filenames)//batch_size),
    epochs=5,
    validation_data=validation_generator,
    validation_steps=(len(validation_generator.filenames)//batch_size),
    
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True),
        ModelCheckpoint(filepath='model3-.{epoch:02d}-{val_loss:.2f}.hdf5', verbose=1, save_best_only=True),
        ReduceLROnPlateau(patience=2)
    ]
)
